# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x1=[2,2,2,2,4,6]
y1=[8,6,4,2,2,2]

x2=[-1,-0.5,0,0.5,1,0.5,0,-0.5,-1]
y2=[0,0.8,1,0.8,0,-0.8,-1,-0.8,0]

x3=[-6,-4,-2,0,2,4,6]
y3=[6,4,2,0,2,4,6]

x4=[8,6,4,2,2,2,4,6,8,6,4,2,2,2,4,6,8]
y4=[10,10,10,10,8,6,6,6,6,6,6,6,4,2,2,2,2]

plt.subplot(231)
plt.plot(x1,y1,"red",lw=4)

plt.subplot(233)
plt.plot(x2,y2,"red",lw=4)

plt.subplot(234)
plt.plot(x3,y3,"red",lw=4)

plt.subplot(236)
plt.plot(x4,y4,"red",lw=4)
