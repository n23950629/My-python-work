# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 大專院校圖書館統計

# %%
df=pd.read_csv("http://stats.moe.gov.tw/files/detail/107/107_library2.csv")

# %%
df.head()
# Out:
#    學校代碼      學校名稱  中文圖書收藏冊數(冊)-總類  中文圖書收藏冊數(冊)-哲學類  中文圖書收藏冊數(冊)-宗教類  \
# 0     1    國立政治大學          326716            50264            37698
# 1     2    國立清華大學           80330            45612            25154
# 2     3    國立臺灣大學          144181            71021            43498
# 3     4  國立臺灣師範大學          142017            74321            24630
# 4     5    國立成功大學          191300            35686            22415
#
#    中文圖書收藏冊數(冊)-科學類  中文圖書收藏冊數(冊)-應用科學類  中文圖書收藏冊數(冊)-社會科學類  中文圖書收藏冊數(冊)-史地類  \
# 0            31415              75396             301584           213622
# 1            70903              87839             216160           129770
# 2           114475             325568             429073           281869
# 3            62745              77572             256911           161588
# 4            43386             108872             126172           103013
#
#    中文圖書收藏冊數(冊)-語言文學類  ...  電子期刊(種)   電子書(種)  視聽資料(件)  圖書閱覽座位數(個)  \
# ...

# %%
len(df)
# Out:
# 153

# %%
newdf=df[["學校名稱","中文圖書收藏冊數(冊)-總類","電子書(種)","中.日文期刊(種)","西文期刊(種)","電子期刊(種)","視聽資料(件)","報紙(種)"]]

# %%
df=df.drop("中文圖書收藏冊數(冊)-哲學類",axis=1)
df=df.drop("中文圖書收藏冊數(冊)-宗教類",axis=1)
df=df.drop("中文圖書收藏冊數(冊)-科學類",axis=1)
df=df.drop("中文圖書收藏冊數(冊)-應用科學類",axis=1)
df=df.drop("中文圖書收藏冊數(冊)-社會科學類",axis=1)
df=df.drop("中文圖書收藏冊數(冊)-史地類",axis=1)
df=df.drop("中文圖書收藏冊數(冊)-語言文學類",axis=1)
df=df.drop("中文圖書收藏冊數(冊)-藝術類",axis=1)

# %%
df.head()
# Out:
#    學校代碼      學校名稱  中文圖書收藏冊數(冊)-總類  外文圖書收藏冊數(冊)  期刊合訂本(未以圖書編目)(冊)  線上資料庫(種)  \
# 0     1    國立政治大學          326716       616699            232297       249
# 1     2    國立清華大學           80330       428959            373368       449
# 2     3    國立臺灣大學          144181      2402487            883553       598
# 3     4  國立臺灣師範大學          142017       523230            130979       352
# 4     5    國立成功大學          191300       590397            442997       560
#
#    光碟及其他類型資料庫(種)  電子期刊(種)   電子書(種)  視聽資料(件)  圖書閱覽座位數(個)  \
# 0             34    60524   741894    24603        2978
# 1              0   150970  3546844   122765        3440
# 2              0    54046  3206992   184316        3938
# 3              0   107991  2649583    75182        1182
# 4             26    75040   784869    58257        2663
#
#    全年圖書(含視聽資料及其他館藏)借閱人次(人次)  全年圖書(含視聽資料及其他館藏)借閱冊次(冊次)  \
# 0                    128733                    386198
# 1                    168306                    461470
# ...

# %%
df=df.drop("圖書閱覽座位數(個)",axis=1)

df=df.drop("全年圖書(含視聽資料及其他館藏)借閱人次(人次)",axis=1)
df=df.drop("全年圖書(含視聽資料及其他館藏)借閱冊次(冊次)",axis=1)
df=df.drop("全年線上及光碟資料庫(含電子書及電子期刊)檢索(人次)",axis=1)

# %%
df.head()
# Out:
#    學校代碼      學校名稱  中文圖書收藏冊數(冊)-總類  外文圖書收藏冊數(冊)  期刊合訂本(未以圖書編目)(冊)  線上資料庫(種)  \
# 0     1    國立政治大學          326716       616699            232297       249
# 1     2    國立清華大學           80330       428959            373368       449
# 2     3    國立臺灣大學          144181      2402487            883553       598
# 3     4  國立臺灣師範大學          142017       523230            130979       352
# 4     5    國立成功大學          191300       590397            442997       560
#
#    光碟及其他類型資料庫(種)  電子期刊(種)   電子書(種)  視聽資料(件)  報紙(種)  中.日文期刊(種)  西文期刊(種)
# 0             34    60524   741894    24603     87       1826     1403
# 1              0   150970  3546844   122765     27       2133      785
# 2              0    54046  3206992   184316     27       1990     1193
# 3              0   107991  2649583    75182     14        969     1492
# 4             26    75040   784869    58257     16       1809      171

# %% [markdown]
# # 圖書資源總排名

# %%
newdf["總數"]=newdf.loc[:,"中文圖書收藏冊數(冊)-總類":"西文期刊(種)"].sum(axis=1)

# %%
newdf_sort=newdf.sort_values("總數",ascending=False)

# %%
newdf_sort
# Out:
#            學校名稱  中文圖書收藏冊數(冊)-總類   電子書(種)  中.日文期刊(種)  西文期刊(種)  電子期刊(種)  \
# 52       中國文化大學          128892  5803536        473      273    67259
# 1        國立清華大學           80330  3546844       2133      785   150970
# 2        國立臺灣大學          144181  3206992       1990     1193    54046
# 70       崑山科技大學           23336  3193530        852      236    23041
# 3      國立臺灣師範大學          142017  2649583        969     1492   107991
# 48         輔仁大學           76172  2603549       1166      529    45128
# 51         淡江大學           87549  2585059        923      458    71730
# 53         逢甲大學           44233  2573637        906      175    48159
# 50         中原大學           14864  1980108        981      144    65217
# 29     國立臺南藝術大學            6800  1982149        294      155    32876
# 43     國立高雄科技大學           40324  1894734       3328     1539    89122
# 49         東吳大學           89164  1752852        724      154    36750
# ...

# %%
len(newdf)
# Out:
# 153

# %% [markdown]
# # 正式的排行榜

# %%
newdf_sort.index = range(1, 154)

# %%
newdf_sort
# Out:
#            學校名稱  中文圖書收藏冊數(冊)-總類   電子書(種)  中.日文期刊(種)  西文期刊(種)  電子期刊(種)  \
# 1        中國文化大學          128892  5803536        473      273    67259
# 2        國立清華大學           80330  3546844       2133      785   150970
# 3        國立臺灣大學          144181  3206992       1990     1193    54046
# 4        崑山科技大學           23336  3193530        852      236    23041
# 5      國立臺灣師範大學          142017  2649583        969     1492   107991
# 6          輔仁大學           76172  2603549       1166      529    45128
# 7          淡江大學           87549  2585059        923      458    71730
# 8          逢甲大學           44233  2573637        906      175    48159
# 9          中原大學           14864  1980108        981      144    65217
# 10     國立臺南藝術大學            6800  1982149        294      155    32876
# 11     國立高雄科技大學           40324  1894734       3328     1539    89122
# 12         東吳大學           89164  1752852        724      154    36750
# ...

# %% [markdown]
# # 好奇我們的排名嗎？

# %%
newdf_sort[newdf_sort.學校名稱=='國立政治大學']
# Out:
#       學校名稱  中文圖書收藏冊數(冊)-總類  電子書(種)  中.日文期刊(種)  西文期刊(種)  電子期刊(種)  視聽資料(件)  \
# 19  國立政治大學          326716  741894       1826     1403    60524    24603
#
#     報紙(種)       總數
# 19     87  1071839
