# %% [markdown]
# # 歌曲推薦器

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import display,HTML,Markdown,Image,YouTubeVideo
from ipywidgets import interact

# %%
A=YouTubeVideo("yjWwfDW9IoA")
B=YouTubeVideo("SxGLPVvNjvY")
C=YouTubeVideo("7nnYqnkLW_Q")
D=YouTubeVideo("7XFTUGtz_lk")
print("哈囉！讓我來為你推薦一首歌吧！")
print("－－－－－－－－－－－－－－－－")
print("請問你想要哪種語言的呢～")
def a(我想要):
    print(我想要)
interact(a,我想要=dict(中文=[display(A)],
                   英文=[display(B)],
                   台語=[display(C)],
                   日語=[display(D)]))
# Out:
# 哈囉！讓我來為你推薦一首歌吧！
# －－－－－－－－－－－－－－－－
# 請問你想要哪種語言的呢～
# interactive(children=(Dropdown(description='我想要', options={'中文': [None], '英文': [None], '台語': [None], '日語': [No…
# <function __main__.a(我想要)>
